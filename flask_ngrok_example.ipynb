# %%
#run in colab 


# !pip install flask-ngrok # check
# !pip install flask==0.12.2  # Newer versions of flask don't work in Colab
# !pip install pyngrok==4.1.1
# !ngrok authtoken '<your-key-here>'
# See https://github.com/plotly/dash/issues/257
# Out:
# ...
#      |████████████████████████████████| 83 kB 1.1 MB/s
# ...
#   Attempting uninstall: flask
#     Found existing installation: Flask 1.1.4
#     Uninstalling Flask-1.1.4:
#       Successfully uninstalled Flask-1.1.4
# ...
#   Created wheel for pyngrok: filename=pyngrok-4.1.1-py3-none-any.whl size=15983 sha256=92e34111a6b6f052c75549a6a2a00456e167bf3b88b43a9a2e91888653b0cda0
#   Stored in directory: /root/.cache/pip/wheels/b1/d9/12/045a042fee3127dc40ba6f5df2798aa2df38c414bf533ca765
# Successfully built pyngrok
# ...
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/huanchen1107/0517/blob/main/flask_ngrok_example.ipynb)

# %%
# flask_ngrok_example.py ok
from flask import Flask
from flask_ngrok import run_with_ngrok

app = Flask(__name__)
run_with_ngrok(app)  # Start ngrok when app is run

@app.route("/")
def hello():
    return "Hello World!"

if __name__ == '__main__':
    app.run()  # If address is in use, may need to terminate other sessions:
               # Runtime > Manage Sessions > Terminate Other Sessions
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://eb32-34-123-192-194.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [17/May/2022 03:15:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/May/2022 03:15:26] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/May/2022 03:15:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/May/2022 03:15:55] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/May/2022 03:15:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/May/2022 03:15:58] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/May/2022 03:16:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/May/2022 03:16:00] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/May/2022 03:16:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/May/2022 03:16:05] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/May/2022 03:16:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/May/2022 03:16:07] "GET /favicon.ico HTTP/1.1" 404 -
# ...
